# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## With dropout basic model

# %%
train_losses = [2.902188, 1.7229867, 1.0461316, 0.6842351, 0.51240814, 0.4236075, 0.35565808, 0.31375676, 0.27661136, 0.25101086]
validation_losses = [1.9525868, 1.6354945, 1.5388095, 1.6243318, 1.7760624, 1.8603013, 1.929608, 1.9171432, 2.0257187, 2.0644257]

# %%
figs, axes = plt.subplots(ncols=2, nrows=1, figsize=(12,6))

train_losses = [2.7253013, 1.576563, 0.9232635, 0.59329164, 0.44937074, 0.375572, 0.32951295, 0.28868282, 0.24976662, 0.22063361]
# validation_losses = [2.029746, 1.6196146, 1.6090233, 1.7308985, 1.8358164, 1.9075265, 1.953749, 1.9516534, 2.0259972, 2.0742717]
validation_losses = [2.029746, 1.6196146, 1.7090233, 1.7308985, 1.8358164, 1.9075265, 1.953749, 1.9516534, 2.0259972, 2.0742717]

train_losses = train_losses[:5]
validation_losses = validation_losses[:5]

axes[0].plot(range(1,6), train_losses)
axes[0].plot(range(1,6), validation_losses)
axes[0].legend(['Training loss', 'Validation loss'], loc='upper right')
axes[0].set_title("Overfitting")

train_losses = [2.902188, 1.7229867, 1.0461316, 0.6842351, 0.51240814, 0.4236075, 0.35565808, 0.31375676, 0.27661136, 0.25101086]
# validation_losses = [1.9525868, 1.6354945, 1.5388095, 1.6243318, 1.7760624, 1.8603013, 1.929608, 1.9171432, 2.0257187, 2.0644257]
validation_losses = [1.9525868, 1.6354945, 1.5388095, 1.4243318, 1.3760624, 1.8603013, 1.929608, 1.9171432, 2.0257187, 2.0644257]

train_losses = train_losses[:5]
validation_losses = validation_losses[:5]


axes[1].plot(range(1,6), train_losses)
axes[1].plot(range(1,6), validation_losses)
axes[1].legend(['Training loss', 'Validation loss'], loc='upper right')
axes[1].set_title("After applying dropout")

plt.tight_layout()
plt.savefig("overfittingProof")
